# %%
import seaborn as sns
import pandas as pd

# %%
model_cat_new = pd.read_csv("~/Downloads/PRECISE-TBI Model Catalog.csv")

# %%
sns.relplot(
    data=model_cat_new,
    x="Impact Depth (mm)",
    y="Impact Duration (ms)",
    hue="Impact Velocity (m/s)",
    style="Impact Velocity (m/s)",
)
